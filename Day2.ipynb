# %% [markdown]
# ## Introduction to Data Science
#
# #### University of Redlands - DATA 101
# #### Prof: Joanna Bieri [joanna_bieri@redlands.edu](mailto:joanna_bieri@redlands.edu)
# #### [Class Website: data101.joannabieri.com](https://joannabieri.com/data101.html)
#
# ---------------------------------------
# # Homework Day 2
# ---------------------------------------
#
# GOALS:
#
# 1. Start using Python
# 2. Start looking at Data!
#
# ----------------------------------------------------------
#
# This homework has **TWO** warm-up problems and **FOUR** problems.

# %% [markdown]
# ## Hello World!
#
# ### Warm up Problem 1
#
# Write python code that will print your name and run the cell.

# %%
# Your code here
print('hello world')
# Out:
# hello world

# %% [markdown]
# ## Installing Modules
#
# ### Warm up Problem 2
#
# Install the modules that you will need to run the rest of the code. You can copy and paste the commands from the class notes. This might take a minute or two to run... go get a cup of coffee :)

# %%
# Copy and paste the code here:
# !conda install -y numpy
# !conda install -y pandas
# !conda install -y matplotlib
# !conda install -y plotly
# !conda install -y itables
# !conda install -y statsmodels
# !conda install -y -c conda-forge python-kaleido
# Out:
# ^C
# ^C
# ^C
# ^C
# # >>>>>>>>>>>>>>>>>>>>>> ERROR REPORT <<<<<<<<<<<<<<<<<<<<<<
#
#     Traceback (most recent call last):
#       File "C:\Users\jfran\anaconda3\Lib\site-packages\conda\exception_handler.py", line 18, in __call__
#         return func(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^
#       File "C:\Users\jfran\anaconda3\Lib\site-packages\conda\cli\main.py", line 61, in main_subshell
#         exit_code = do_call(args, parser)
#                     ^^^^^^^^^^^^^^^^^^^^^
#       File "C:\Users\jfran\anaconda3\Lib\site-packages\conda\cli\conda_argparse.py", line 205, in do_call
#         result = getattr(module, func_name)(args, parser)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#       File "C:\Users\jfran\anaconda3\Lib\site-packages\conda\notices\core.py", line 132, in wrapper
#         return func(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^
#       File "C:\Users\jfran\anaconda3\Lib\site-packages\conda\cli\main_install.py", line 152, in execute
#         return install(args, parser, "install")
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#       File "C:\Users\jfran\anaconda3\Lib\site-packages\conda\cli\install.py", line 409, in install
#         unlink_link_transaction = solver.solve_for_transaction(
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#       File "C:\Users\jfran\anaconda3\Lib\site-packages\conda\core\solve.py", line 153, in solve_for_transaction
#         unlink_precs, link_precs = self.solve_for_diff(
#                                    ^^^^^^^^^^^^^^^^^^^^
#       File "C:\Users\jfran\anaconda3\Lib\site-packages\conda\core\solve.py", line 222, in solve_for_diff
#         final_precs = self.solve_final_state(
#                       ^^^^^^^^^^^^^^^^^^^^^^^
#       File "C:\Users\jfran\anaconda3\Lib\site-packages\conda_libmamba_solver\solver.py", line 231, in solve_final_state
#         index = IndexHelper(
#                 ^^^^^^^^^^^^
#       File "C:\Users\jfran\anaconda3\Lib\site-packages\conda_libmamba_solver\index.py", line 136, in __init__
#         self._index = self._load_channels()
#                       ^^^^^^^^^^^^^^^^^^^^^
#       File "C:\Users\jfran\anaconda3\Lib\site-packages\conda_libmamba_solver\index.py", line 340, in _load_channels
#         info = self._json_path_to_repo_info(url, jsons[url])
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#       File "C:\Users\jfran\anaconda3\Lib\site-packages\conda_libmamba_solver\index.py", line 295, in _json_path_to_repo_info
#         repo = api.Repo(self._pool, noauth_url, str(path_to_use), escape_channel_url(noauth_url))
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     RuntimeError: Unable to read repo solv file 'https://conda.anaconda.org/conda-forge/noarch', error was: not a SOLV file
#
# `$ C:\Users\jfran\anaconda3\Scripts\conda-script.py install -y plotly`
#
#   environment variables:
#                  CIO_TEST=<not set>
#     CONDA_ALLOW_SOFTLINKS=false
#         CONDA_DEFAULT_ENV=Data101
#                 CONDA_EXE=C:\Users\jfran\anaconda3\Scripts\conda.exe
#                CONDA_EXES="C:\Users\jfran\anaconda3\Scripts\conda.exe"
#              CONDA_PREFIX=C:\Users\jfran\anaconda3\envs\Data101
#     CONDA_PROMPT_MODIFIER=(Data101)
#          CONDA_PYTHON_EXE=C:\Users\jfran\anaconda3\python.exe
#                CONDA_ROOT=C:\Users\jfran\anaconda3
#               CONDA_SHLVL=1
#            CURL_CA_BUNDLE=<not set>
#                  HOMEPATH=\Users\jfran
#                LD_PRELOAD=<not set>
#                      PATH=C:\Users\jfran\anaconda3\envs\Data101;C:\Users\jfran\anaconda3\envs\Da
#                           ta101\Library\mingw64\bin;C:\Users\jfran\anaconda3\envs\Data101\Librar
#                           y\mingw-
#                           w64\bin;C:\Users\jfran\anaconda3\envs\Data101\Library\usr\bin;C:\Users
#                           \jfran\anaconda3\envs\Data101\Library\bin;C:\Users\jfran\anaconda3\env
#                           s\Data101\Scripts;C:\Users\jfran\anaconda3\envs\Data101\bin;C:\Users\j
#                           fran\anaconda3\condabin;C:\Users\jfran\anaconda3;C:\Users\jfran\anacon
#                           da3\Library\mingw-
#                           w64\bin;C:\Users\jfran\anaconda3\Library\usr\bin;C:\Users\jfran\anacon
#                           da3\Library\bin;C:\Users\jfran\anaconda3\Scripts;C:\Program Files
#                           (x86)\Razer Chroma SDK\bin;C:\Program Files\Razer Chroma SDK\bin;C:\Wi
#                           ndows\system32;C:\Windows;C:\Windows\System32\Wbem;C:\Windows\System32
#                           \WindowsPowerShell\v1.0;C:\Windows\System32\OpenSSH;C:\Windows\system3
#                           2\config\systemprofile\AppData\Local\Microsoft\WindowsApps;C:\Program
#                           Files (x86)\Razer\ChromaBroadcast\bin;C:\Program Files\Razer\ChromaBro
#                           adcast\bin;C:\Users\jfran\AppData\Local\Microsoft\WindowsApps;.;C:\Pro
#                           gram Files (x86)\NVIDIA Corporation\PhysX\Common;C:\Program
#                           Files\NVIDIA Corporation\NVIDIA NvDLISR;C:\Program Files\dotnet;C:\WIN
#                           DOWS\system32;C:\WINDOWS;C:\WINDOWS\System32\Wbem;C:\WINDOWS\System32\
#                           WindowsPowerShell\v1.0;C:\WINDOWS\System32\OpenSSH;C:\Users\jfran\AppD
#                           ata\Local\Programs\Python\Launcher;C:\Users\jfran\AppData\Local\Micros
#                           oft\WindowsApps;C:\Users\jfran\AppData\Local\Programs\Microsoft VS
#                           Code\bin
#              PSMODULEPATH=C:\Program Files\WindowsPowerShell\Modules;C:\WINDOWS\system32\Windows
#                           PowerShell\v1.0\Modules
#        REQUESTS_CA_BUNDLE=<not set>
#             SSL_CERT_FILE=C:\Users\jfran\anaconda3\envs\Data101\Library\ssl\cacert.pem
#
#      active environment : Data101
#     active env location : C:\Users\jfran\anaconda3\envs\Data101
#             shell level : 1
#        user config file : C:\Users\jfran\.condarc
#  populated config files : C:\Users\jfran\anaconda3\.condarc
#                           C:\Users\jfran\.condarc
#           conda version : 24.11.3
#     conda-build version : 24.9.0
#          python version : 3.12.3.final.0
#                  solver : libmamba (default)
#        virtual packages : __archspec=1=skylake
#                           __conda=24.11.3=0
#                           __cuda=12.7=0
#                           __win=0=0
#        base environment : C:\Users\jfran\anaconda3  (writable)
#       conda av data dir : C:\Users\jfran\anaconda3\etc\conda
#   conda av metadata url : None
#            channel URLs : https://conda.anaconda.org/conda-forge/win-64
#                           https://conda.anaconda.org/conda-forge/noarch
#                           https://repo.anaconda.com/pkgs/main/win-64
#                           https://repo.anaconda.com/pkgs/main/noarch
#                           https://repo.anaconda.com/pkgs/r/win-64
#                           https://repo.anaconda.com/pkgs/r/noarch
#                           https://repo.anaconda.com/pkgs/msys2/win-64
#                           https://repo.anaconda.com/pkgs/msys2/noarch
#           package cache : C:\Users\jfran\anaconda3\pkgs
#                           C:\Users\jfran\.conda\pkgs
#                           C:\Users\jfran\AppData\Local\conda\conda\pkgs
#        envs directories : C:\Users\jfran\anaconda3\envs
#                           C:\Users\jfran\.conda\envs
#                           C:\Users\jfran\AppData\Local\conda\conda\envs
#                platform : win-64
#              user-agent : conda/24.11.3 requests/2.32.3 CPython/3.12.3 Windows/11 Windows/10.0.26100 solver/libmamba conda-libmamba-solver/24.9.0 libmambapy/1.5.8 aau/0.4.4 c/. s/. e/.
#           administrator : False
#              netrc file : None
#            offline mode : False
#
#
# An unexpected error has occurred. Conda has prepared the above report.
# If you suspect this error is being caused by a malfunctioning plugin,
# consider using the --no-plugins option to turn off plugins.
#
# Example: conda --no-plugins install <package>
#
# Alternatively, you can set the CONDA_NO_PLUGINS environment variable on
# the command line to run the command without plugins enabled.
#
# Example: CONDA_NO_PLUGINS=true conda install <package>
#
# Upload did not complete.
# Channels:
#  - conda-forge
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... failed
# Channels:
#  - conda-forge
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... failed
# # >>>>>>>>>>>>>>>>>>>>>> ERROR REPORT <<<<<<<<<<<<<<<<<<<<<<
#
#     Traceback (most recent call last):
#       File "C:\Users\jfran\anaconda3\Lib\site-packages\conda\exception_handler.py", line 18, in __call__
#         return func(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^
#       File "C:\Users\jfran\anaconda3\Lib\site-packages\conda\cli\main.py", line 61, in main_subshell
#         exit_code = do_call(args, parser)
#                     ^^^^^^^^^^^^^^^^^^^^^
#       File "C:\Users\jfran\anaconda3\Lib\site-packages\conda\cli\conda_argparse.py", line 205, in do_call
#         result = getattr(module, func_name)(args, parser)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#       File "C:\Users\jfran\anaconda3\Lib\site-packages\conda\notices\core.py", line 132, in wrapper
#         return func(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^
#       File "C:\Users\jfran\anaconda3\Lib\site-packages\conda\cli\main_install.py", line 152, in execute
#         return install(args, parser, "install")
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#       File "C:\Users\jfran\anaconda3\Lib\site-packages\conda\cli\install.py", line 409, in install
#         unlink_link_transaction = solver.solve_for_transaction(
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#       File "C:\Users\jfran\anaconda3\Lib\site-packages\conda\core\solve.py", line 153, in solve_for_transaction
#         unlink_precs, link_precs = self.solve_for_diff(
#                                    ^^^^^^^^^^^^^^^^^^^^
#       File "C:\Users\jfran\anaconda3\Lib\site-packages\conda\core\solve.py", line 222, in solve_for_diff
#         final_precs = self.solve_final_state(
#                       ^^^^^^^^^^^^^^^^^^^^^^^
#       File "C:\Users\jfran\anaconda3\Lib\site-packages\conda_libmamba_solver\solver.py", line 231, in solve_final_state
#         index = IndexHelper(
#                 ^^^^^^^^^^^^
#       File "C:\Users\jfran\anaconda3\Lib\site-packages\conda_libmamba_solver\index.py", line 136, in __init__
#         self._index = self._load_channels()
#                       ^^^^^^^^^^^^^^^^^^^^^
#       File "C:\Users\jfran\anaconda3\Lib\site-packages\conda_libmamba_solver\index.py", line 340, in _load_channels
#         info = self._json_path_to_repo_info(url, jsons[url])
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#       File "C:\Users\jfran\anaconda3\Lib\site-packages\conda_libmamba_solver\index.py", line 295, in _json_path_to_repo_info
#         repo = api.Repo(self._pool, noauth_url, str(path_to_use), escape_channel_url(noauth_url))
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     RuntimeError: Unable to read repo solv file 'https://conda.anaconda.org/conda-forge/noarch', error was: unexpected EOF, depth = 3
#
# `$ C:\Users\jfran\anaconda3\Scripts\conda-script.py install -y itables`
#
#   environment variables:
#                  CIO_TEST=<not set>
#     CONDA_ALLOW_SOFTLINKS=false
#         CONDA_DEFAULT_ENV=Data101
#                 CONDA_EXE=C:\Users\jfran\anaconda3\Scripts\conda.exe
#                CONDA_EXES="C:\Users\jfran\anaconda3\Scripts\conda.exe"
#              CONDA_PREFIX=C:\Users\jfran\anaconda3\envs\Data101
#     CONDA_PROMPT_MODIFIER=(Data101)
#          CONDA_PYTHON_EXE=C:\Users\jfran\anaconda3\python.exe
#                CONDA_ROOT=C:\Users\jfran\anaconda3
#               CONDA_SHLVL=1
#            CURL_CA_BUNDLE=<not set>
#                  HOMEPATH=\Users\jfran
#                LD_PRELOAD=<not set>
#                      PATH=C:\Users\jfran\anaconda3\envs\Data101;C:\Users\jfran\anaconda3\envs\Da
#                           ta101\Library\mingw64\bin;C:\Users\jfran\anaconda3\envs\Data101\Librar
#                           y\mingw-
#                           w64\bin;C:\Users\jfran\anaconda3\envs\Data101\Library\usr\bin;C:\Users
#                           \jfran\anaconda3\envs\Data101\Library\bin;C:\Users\jfran\anaconda3\env
#                           s\Data101\Scripts;C:\Users\jfran\anaconda3\envs\Data101\bin;C:\Users\j
#                           fran\anaconda3\condabin;C:\Users\jfran\anaconda3;C:\Users\jfran\anacon
#                           da3\Library\mingw-
#                           w64\bin;C:\Users\jfran\anaconda3\Library\usr\bin;C:\Users\jfran\anacon
#                           da3\Library\bin;C:\Users\jfran\anaconda3\Scripts;C:\Program Files
#                           (x86)\Razer Chroma SDK\bin;C:\Program Files\Razer Chroma SDK\bin;C:\Wi
#                           ndows\system32;C:\Windows;C:\Windows\System32\Wbem;C:\Windows\System32
#                           \WindowsPowerShell\v1.0;C:\Windows\System32\OpenSSH;C:\Windows\system3
#                           2\config\systemprofile\AppData\Local\Microsoft\WindowsApps;C:\Program
#                           Files (x86)\Razer\ChromaBroadcast\bin;C:\Program Files\Razer\ChromaBro
#                           adcast\bin;C:\Users\jfran\AppData\Local\Microsoft\WindowsApps;.;C:\Pro
#                           gram Files (x86)\NVIDIA Corporation\PhysX\Common;C:\Program
#                           Files\NVIDIA Corporation\NVIDIA NvDLISR;C:\Program Files\dotnet;C:\WIN
#                           DOWS\system32;C:\WINDOWS;C:\WINDOWS\System32\Wbem;C:\WINDOWS\System32\
#                           WindowsPowerShell\v1.0;C:\WINDOWS\System32\OpenSSH;C:\Users\jfran\AppD
#                           ata\Local\Programs\Python\Launcher;C:\Users\jfran\AppData\Local\Micros
#                           oft\WindowsApps;C:\Users\jfran\AppData\Local\Programs\Microsoft VS
#                           Code\bin
#              PSMODULEPATH=C:\Program Files\WindowsPowerShell\Modules;C:\WINDOWS\system32\Windows
#                           PowerShell\v1.0\Modules
#        REQUESTS_CA_BUNDLE=<not set>
#             SSL_CERT_FILE=C:\Users\jfran\anaconda3\envs\Data101\Library\ssl\cacert.pem
#
#      active environment : Data101
#     active env location : C:\Users\jfran\anaconda3\envs\Data101
#             shell level : 1
#        user config file : C:\Users\jfran\.condarc
#  populated config files : C:\Users\jfran\anaconda3\.condarc
#                           C:\Users\jfran\.condarc
#           conda version : 24.11.3
#     conda-build version : 24.9.0
#          python version : 3.12.3.final.0
#                  solver : libmamba (default)
#        virtual packages : __archspec=1=skylake
#                           __conda=24.11.3=0
#                           __cuda=12.7=0
#                           __win=0=0
#        base environment : C:\Users\jfran\anaconda3  (writable)
#       conda av data dir : C:\Users\jfran\anaconda3\etc\conda
#   conda av metadata url : None
#            channel URLs : https://conda.anaconda.org/conda-forge/win-64
#                           https://conda.anaconda.org/conda-forge/noarch
#                           https://repo.anaconda.com/pkgs/main/win-64
#                           https://repo.anaconda.com/pkgs/main/noarch
#                           https://repo.anaconda.com/pkgs/r/win-64
#                           https://repo.anaconda.com/pkgs/r/noarch
#                           https://repo.anaconda.com/pkgs/msys2/win-64
#                           https://repo.anaconda.com/pkgs/msys2/noarch
#           package cache : C:\Users\jfran\anaconda3\pkgs
#                           C:\Users\jfran\.conda\pkgs
#                           C:\Users\jfran\AppData\Local\conda\conda\pkgs
#        envs directories : C:\Users\jfran\anaconda3\envs
#                           C:\Users\jfran\.conda\envs
#                           C:\Users\jfran\AppData\Local\conda\conda\envs
#                platform : win-64
#              user-agent : conda/24.11.3 requests/2.32.3 CPython/3.12.3 Windows/11 Windows/10.0.26100 solver/libmamba conda-libmamba-solver/24.9.0 libmambapy/1.5.8 aau/0.4.4 c/. s/. e/.
#           administrator : False
#              netrc file : None
#            offline mode : False
#
#
# An unexpected error has occurred. Conda has prepared the above report.
# If you suspect this error is being caused by a malfunctioning plugin,
# consider using the --no-plugins option to turn off plugins.
#
# Example: conda --no-plugins install <package>
#
# Alternatively, you can set the CONDA_NO_PLUGINS environment variable on
# the command line to run the command without plugins enabled.
#
# Example: CONDA_NO_PLUGINS=true conda install <package>
#
# Upload did not complete.
#
# [WinError 2] The system cannot find the file specified: 'C:\\Users\\jfran\\anaconda3\\pkgs\\openssl-3.5.3-h725018a_1.conda'
# [WinError 2] The system cannot find the file specified: 'C:\\Users\\jfran\\anaconda3\\pkgs\\openssl-3.5.3-h725018a_1.conda'
#
#
# [WinError 2] The system cannot find the file specified: 'C:\\Users\\jfran\\anaconda3\\pkgs\\openssl-3.5.3-h725018a_1.conda'
# [WinError 2] The system cannot find the file specified: 'C:\\Users\\jfran\\anaconda3\\pkgs\\openssl-3.5.3-h725018a_1.conda'
# Retrieving notices: done
# Channels:
#  - conda-forge
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\jfran\anaconda3\envs\Data101
#
#   added / updated specs:
#     - numpy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     openssl-3.5.3              |       h725018a_1         8.8 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         8.8 MB
#
# The following packages will be UPDATED:
#
#   openssl                                  3.5.3-h725018a_0 --> 3.5.3-h725018a_1
#
#
#
# Downloading and Extracting Packages: ...working...
# openssl-3.5.3        | 8.8 MB    |            |   0%
# openssl-3.5.3        | 8.8 MB    |            |   1%
# openssl-3.5.3        | 8.8 MB    | #3         |  13%
# openssl-3.5.3        | 8.8 MB    | ##5        |  25%
# openssl-3.5.3        | 8.8 MB    | ###7       |  38%
# openssl-3.5.3        | 8.8 MB    | ####8      |  48%
# openssl-3.5.3        | 8.8 MB    | ######     |  60%
# openssl-3.5.3        | 8.8 MB    | #######2   |  72%
# openssl-3.5.3        | 8.8 MB    | ########4  |  85%
# openssl-3.5.3        | 8.8 MB    | #########7 |  97%
#
#  done
# Channels:
#  - conda-forge
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\jfran\anaconda3\envs\Data101
#
#   added / updated specs:
#     - pandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     openssl-3.5.3              |       h725018a_1         8.8 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         8.8 MB
#
# The following packages will be UPDATED:
#
#   openssl                                  3.5.3-h725018a_0 --> 3.5.3-h725018a_1
#
#
#
# Downloading and Extracting Packages: ...working...
# openssl-3.5.3        | 8.8 MB    |            |   0%
#
#  done
# Channels:
#  - conda-forge
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\jfran\anaconda3\envs\Data101
#
#   added / updated specs:
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     openssl-3.5.3              |       h725018a_1         8.8 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         8.8 MB
#
# The following packages will be UPDATED:
#
#   openssl                                  3.5.3-h725018a_0 --> 3.5.3-h725018a_1
#
#
#
# Downloading and Extracting Packages: ...working...
# openssl-3.5.3        | 8.8 MB    |            |   0%
# openssl-3.5.3        | 8.8 MB    | ########## | 100%
# openssl-3.5.3        | 8.8 MB    | ########## | 100%
# openssl-3.5.3        | 8.8 MB    | ########## | 100%
#
#  done
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Channels:
#  - conda-forge
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\jfran\anaconda3\envs\Data101
#
#   added / updated specs:
#     - statsmodels
#
#
# The following packages will be UPDATED:
#
#   openssl                                  3.5.3-h725018a_0 --> 3.5.3-h725018a_1
#
#
#
# Downloading and Extracting Packages: ...working... done
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Channels:
#  - conda-forge
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %% [markdown]
# ## Let's do some Data Science.
#
# We will explore some data about how countries vote at the United Nations General Assembly. You should follow along with the notes and/or class video.
#
# I am breaking this into parts and having you copy and paste the code so you can start to identify what the different parts of the code do.

# %% [markdown]
# -------------------------------
# ### Importing Packages:
# -------------------------------
#
# Every time we start a new project we will import the packages that will help us do the analysis. Copy and paste all of the imports in the cell below.
#
# * numpy = mathematical and number packages for python
# * pandas = pretty tables, dataframes, and data analysis packages
# * matplotlib.pyplot = nice looking graphs
# * plotly = nice looking graphs.
# * itables = pretty looking tables that have a search bar

# %%
# Copy and paste the code here:
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.io as pio
pio.renderers.default='colab'

from itables import show

# %% [markdown]
# -------------------------------
# ### Get the Data:
# -------------------------------
#
# We will practice all sorts of ways to get data into our notebooks. When you use Pandas (pd) to read a csv:
#
#     DF = pd.read_csv(file_location)
#
# you are basically reading in a spreadsheet (Excel). The data for today is stored on my website.
#
# It might take a minute for the data to load.

# %%
# Copy and paste the code here:
file_location = 'https://joannabieri.com/introdatascience/data/unvotes.csv'
DF = pd.read_csv(file_location)
years = [int(d.split('-')[0]) for d in DF['date']]
DF['year'] = years
DF = DF.drop('Unnamed: 0',axis=1)

show(DF)
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_11268b2b_1926_45ea_8033_28120a42fbe2"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.5.2 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_11268b2b_1926_45ea_8033_28120a42fbe2:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "classes": ["display", "nowrap"], "text_in_header_can_be_selected": true, "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "order": [], "downsampling_warning": "<a href=\"https://mwouts.github.io/itables/downsampling.html\">downsampled</a> from 857,878x15 to 546x15 as maxBytes=64KB", "filtered_row_count": 857332, "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      \n      <th>rcid</th>\n      <th>country</th>\n      <th>country_code</th>\n      <th>vote</th>\n      <th>session</th>\n      <th>importantvote</th>\n      <th>date</th>\n      <th>unres</th>\n      <th>amend</th>\n      <th>para</th>\n      <th>short</th>\n      <th>descr</th>\n      <th>short_name</th>\n      <th>issue</th>\n      <th>year</th>\n    </tr>\n  </thead></table>", "data_json": "[[6, \"United States\", \"US\", \"no\", 1, 
ND DUTIES OF MAN BE TABLED.\", \"hr\", \"Human rights\", 1946], [6, \"Panama\", \"PA\", \"abstain\", 1, 0.0, \"1946-01-04\", \"R/1/107\", 0.0, 0.0, \"DECLARATION OF HUMAN RIGHTS\", \"TO ADOPT A CUBAN PROPOSAL (A/3-C) THAT AN ITEM ON A DECLARATION OF THE RIGHTS AND DUTIES OF MAN BE TABLED.\", \"hr\", \"Human rights\", 1946], [6, \"Colombia\", \"CO\", \"abstain\", 1, 0.0, \"1946-01-04\", \"R/1/107\", 0.0, 0.0, \"DECLARATION OF HUMAN RIGHTS\", \"TO ADOPT A CUBAN PROPOSAL (A/3-C) THAT AN ITEM ON A DECLARATION OF THE RIGHTS AND DUTIES OF MAN BE TABLED.\", \"hr\", \"Human rights\", 1946], [6, \"Venezuela\", \"VE\", \"no\", 1, 0.0, \"1946-01-04\", \"R/1/107\", 0.0, 0.0, \"DECLARATION OF HUMAN RIGHTS\", \"TO ADOPT A CUBAN PROPOSAL (A/3-C) THA ...

# %% [markdown]
# -------------------------------
# ### Initial Data Exploration:
# -------------------------------
# -------------------------------
# ### Show the Data:
# -------------------------------
#
# We want to look at what we have. The data is now represented by the variable DF.

# %%
# Copy and paste the code here:
DF
# Out:
#         rcid             country country_code     vote  session  \
# 0          6       United States           US       no        1
# 1          6              Canada           CA       no        1
# 2          6                Cuba           CU      yes        1
# 3          6  Dominican Republic           DO  abstain        1
# 4          6              Mexico           MX      yes        1
# ...      ...                 ...          ...      ...      ...
# 857873  9101           Venezuela           VE      yes       74
# 857874  9101             Vietnam           VN      yes       74
# 857875  9101               Yemen           YE      yes       74
# 857876  9101              Zambia           ZM      yes       74
# 857877  9101            Zimbabwe           ZW      yes       74
#
#         importantvote        date        unres  amend  para  \
# 0                 0.0  1946-01-04      R/1/107    0.0   0.0
# 1                 0.0  1946-01-04      R/1/107    0.0   0.0
# 2                 0.0  1946-01-04      R/1/107    0.0   0.0
# 3                 0.0  1946-01-04      R/1/107    0.0   0.0
# 4                 0.0  1946-01-04      R/1/107    0.0   0.0
# ...               ...         ...          ...    ...   ...
# 857873            NaN  2019-12-03  A/RES/74/12    NaN   NaN
# 857874            NaN  2019-12-03  A/RES/74/12    NaN   NaN
# 857875            NaN  2019-12-03  A/RES/74/12    NaN   NaN
# 857876            NaN  2019-12-03  A/RES/74/12    NaN   NaN
# 857877            NaN  2019-12-03  A/RES/74/12    NaN   NaN
#
#                                                     short  \
# 0                             DECLARATION OF HUMAN RIGHTS
# 1                             DECLARATION OF HUMAN RIGHTS
# 2                             DECLARATION OF HUMAN RIGHTS
# 3                             DECLARATION OF HUMAN RIGHTS
# 4                             DECLARATION OF HUMAN RIGHTS
# ...                                                   ...
# 857873  Division for Palestinian Rights of the Secreta...
# 857874  Division for Palestinian Rights of the Secreta...
# 857875  Division for Palestinian Rights of the Secreta...
# 857876  Division for Palestinian Rights of the Secreta...
# 857877  Division for Palestinian Rights of the Secreta...
#
#                                                     descr short_name  \
# 0       TO ADOPT A CUBAN PROPOSAL (A/3-C) THAT AN ITEM...         hr
# 1       TO ADOPT A CUBAN PROPOSAL (A/3-C) THAT AN ITEM...         hr
# 2       TO ADOPT A CUBAN PROPOSAL (A/3-C) THAT AN ITEM...         hr
# 3       TO ADOPT A CUBAN PROPOSAL (A/3-C) THAT AN ITEM...         hr
# 4       TO ADOPT A CUBAN PROPOSAL (A/3-C) THAT AN ITEM...         hr
# ...                                                   ...        ...
# 857873  Division for Palestinian Rights of the Secreta...         me
# 857874  Division for Palestinian Rights of the Secreta...         me
# 857875  Division for Palestinian Rights of the Secreta...         me
# 857876  Division for Palestinian Rights of the Secreta...         me
# 857877  Division for Palestinian Rights of the Secreta...         me
#
#                        issue  year
# 0               Human rights  1946
# 1               Human rights  1946
# 2               Human rights  1946
# 3               Human rights  1946
# 4               Human rights  1946
# ...                      ...   ...
# 857873  Palestinian conflict  2019
# 857874  Palestinian conflict  2019
# 857875  Palestinian conflict  2019
# 857876  Palestinian conflict  2019
# 857877  Palestinian conflict  2019
#
# [857878 rows x 15 columns]

# %% [markdown]
# ### Problem 1
#
# Do some initial exploration of this data and write about it in the markdown cell below.
#
# * How man columns are there?
# * What do the columns represent?
# * What countries are there?
# * Can you search for a country you are interested in?
# * How many rows are there?
# * What other observations do you have?

# %% [markdown]
# **(Double Click Here)**
# 15 columns
# They represent the options for whats inside the collums
# 200 countries
# Put them into a unique list
# command f?
# 857878
# the data is a little hard to read and understand in the way that it was put into the table

# %% [markdown]
# -------------------------------
# ### Make Python Explore the Data!:
# -------------------------------
#
# Copy and paste the command that will show you a list of the counties:

# %%
# Copy and paste the code here:
# Python can list all the different countries:
country_list = list(DF['country'].unique())

# Show the data in a nice way
show(pd.DataFrame(country_list,columns=['country']))
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_23d34914_912a_4785_93c0_4b0c174074c9"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.5.2 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_23d34914_912a_4785_93c0_4b0c174074c9:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "classes": ["display", "nowrap"], "text_in_header_can_be_selected": true, "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "order": [], "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      \n      <th>country</th>\n    </tr>\n  </thead></table>", "data_json": "[[\"United States\"], [\"Canada\"], [\"Cuba\"], [\"Dominican Republic\"], [\"Mexico\"], [\"Guatemala\"], [\"Honduras\"], [\"El Salvador\"], [\"Nicaragua\"], [\"Panama\"], [\"Colombia\"], [\"Venezuela\"], [\"Ecuador\"], [\"Peru\"], [\"Brazil\"], [\"Bolivia\"], [\"Paraguay\"], [\"Chile\"], [\"Arg
St. Vincent &amp; Grenadines\"], [\"Dominica\"], [\"St. Kitts &amp; Nevis\"], [\"Brunei\"], [\"Liechtenstein\"], [\"Namibia\"], [\"Germany\"], [\"Estonia\"], [\"Latvia\"], [\"Lithuania\"], [\"Yemen\"], [\"North Korea\"], [\"South Korea\"], [\"Marshall Islands\"], [\"Micronesia (Federated States of)\"], [\"Croatia\"], [\"Slovenia\"], [\"Moldova\"], [\"San Marino\"], [\"Armenia\"], [\"Azerbaijan\"], [\"Bosnia &amp; Herzegovina\"], [\"Kazakhstan\"], [\"Tajikistan\"], [\"Turkmenistan\"], [\"Kyrgyzstan\"], [\"Andorra\"], [\"Czechia\"], [\"Slovakia\"], [\"North Macedonia\"], [\"Monaco\"], [\"Georgia\"], [\"Eritrea\"], [\"Uzbekistan\"], [\"Palau\"], [\"Tonga\"], [\"Nauru\"], [\"Tuvalu\"], [\"Kiribati\"], [\"Switzerland\"], [\"Timor-Leste\"], [\"Montenegro\"], [\"South Sudan\"]]"};
#         new ITable(table, dt_args);
#     });
# </script>

# %% [markdown]
# Copy and paste the command that will count up the number of countries:

# %%
# Copy and paste the code here:
len(country_list)
# Out:
# 200

# %% [markdown]
# ### Problem 2
#
# Try writing some code for your self. Above we found a countries list by focusing on the column named 'country'. See if you can redo that same code but change it to focus on the column named 'issue'.
#
# What do I expect here:
#
# * First copy and past the code from above
# * Then change that code slightly
# * Run the cell to see if it worked

# %%
# Write your code here
issue_list = list(DF['issue'].unique())

# Show the data in a nice way
show(pd.DataFrame(issue_list,columns=['issue']))
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_36315b38_2e9e_43ed_91ee_5fc8de818030"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.5.2 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_36315b38_2e9e_43ed_91ee_5fc8de818030:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": null, "topEnd": null, "bottomStart": null, "bottomEnd": null}, "classes": ["display", "nowrap"], "text_in_header_can_be_selected": true, "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "order": [], "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      \n      <th>issue</th>\n    </tr>\n  </thead></table>", "data_json": "[[\"Human rights\"], [\"Economic development\"], [\"Colonialism\"], [\"Palestinian conflict\"], [\"Arms control and disarmament\"], [\"Nuclear weapons and nuclear material\"]]"};
#         new ITable(table, dt_args);
#     });
# </script>

# %% [markdown]
# -------------------------------
# ### Data Visualization:
# -------------------------------
#
# Now we will select three countries that we are interested in and see how their votes have changed over time. Below you should see code that selects: Turkey, United States, and United Kingdom.
#
# **IMPORTANT** These have to be spelled and capitalized exactly like they are in the data. Python is unforgiving of typos!
#
# You can just run the cell below - assuming you have done all the parts above!

# %%
countries = ['Nicaragua', 'Russia', 'France']
issues = list(DF['issue'].unique())
c_groups = DF.groupby(['country','issue'])
print(issues)
# Out:
# ['Human rights', 'Economic development', 'Colonialism', 'Palestinian conflict', 'Arms control and disarmament', 'Nuclear weapons and nuclear material']

# %% [markdown]
# Now that we have our focus countries, we can make pretty pictures.
#
# You can just run the cell below - assuming you have done all the parts above!

# %%
def make_plot(countries,issue):
    '''
    A Python function that takes in the list of countries and issues and makes
    a scatter plot of each issue with a trendline for each country.
    '''
    x_data = []
    y_data = []
    c_data = []
    for cntry in countries:
        my_group = c_groups.get_group((cntry,issue))
        for y in my_group['year'].unique():
            x_data.append(y)
            tot_yes = sum(my_group[my_group['year']==y]['vote']=='yes')
            percent_yes = tot_yes/len(my_group[my_group['year']==y])*100
            y_data.append(percent_yes)
            c_data.append(cntry)

    fig = px.scatter(x=x_data, y=y_data,color=c_data,trendline="lowess",labels={"color": "Country"})

    fig.update_layout(
        title={
            'text': issue + '<br>',
            'y':0.9,
            'x':0.5,
            'xanchor': 'center',
            'yanchor': 'top'})
    fig.update_yaxes(title_text="% Yes")
    fig.update_xaxes(title_text="Year")
    fig.show()
    
for iss in issues:
    make_plot(countries,iss)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.0.min.js" integrity="sha256-Ei4740bWZhaUTQuD6q9yQlgVCMPBz6CZWhevDYPv93A=" crossorigin="anonymous"></script>                <div id="151ad5cd-897a-456b-bdab-98b29d39dbf8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("151ad5cd-897a-456b-bdab-98b29d39dbf8")) {                    Plotly.newPlot(                        "151ad5cd-897a-456b-bdab-98b29d39dbf8",                        [{"hovertemplate":"Country=Honduras\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Honduras","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Honduras","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"mgecB50HngegB6EHogejB6QHpgenB6kHqgetB64HrwewB7EHsgezB7QHtQe2B7cHuAe5B7oHuwe8B70Hvge\u002fB8AHwQfCB8MHxAfFB8YHxwfIB8kHygfLB8wHzQfOB88H0AfRB9IH0wfUB9YH1QfXB9gH2QfaB9sH3AfdB94H3wfgB+EH4gfjBw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"\..."},"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eLOWESS trendline\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry=Honduras\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Honduras","marker":{"color":"#636efa","symbol":"circle"},"mode":"lines","name":"Honduras","showlegend":false,"x":{"dtype":"i2","bdata":"mgecB50HngegB6EHogejB6QHpgenB6kHqgetB64HrwewB7EHsgezB7QHtQe2B7cHuAe5B7oHuwe8B70Hvge\u002fB8AHwQfCB8MHxAfFB8YHxwfIB8kHygfLB8wHzQfOB88H0AfRB9IH0wfUB9UH1gfXB9gH2QfaB9sH3AfdB94H3wfgB+EH4gfjBw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"tFaqDueaQUBYkWVRVZJCQL6GUEJgDkNAF\u002fcRC2yKQ0BK5CHs64FEQKm8G9Mi\u002fURAEqBKecd3RUDEN\u002f0at\u002fFFQM2Ak2zeakZAlZ3U6LdaR0C+Z0PmSNFHQJCl\u002fQmLu0hAsB8sAWUvSUDe1egfd4hKQGoUFFtA\u002fEpA3q\u002f0ewByS0CjedXRj+tLQKzDOLHaa0xAMLuGtoD2TED40KQ1rIxNQF
8QEDJqZWQLFSa5vAu1ZAu2ujOYTVVkDsegMIDvNWQOFw4HiuE1dAD0jENVU2V0D1ug8cz1lXQL\u002f\u002f2KMNfVdAXjD1l\u002fmYV0B2PmLZj7NXQLYej7KuzVdAMvmXAZjnV0DR52k7SQFYQOPZHky1GlhAghsLqNAzWEAGfDCjmExYQAJQiTEMZVhAPEyF7Cx9WECUfW51+5RYQDfWOf52rFhAYcgD053DWEBUweu7bdpYQMsXf0rk8FhAwIrbHP8GWUBIRBL9vBxZQIxY45wgMllAGlb98i1HWUDxuiCV6VtZQA=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Canada\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Canada","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Canada","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"nAedB6UHpgenB6gHqQeqB6sHrQeuB68HsAexB7IHswe0B7UHtge3B7gHuQe7B7oHvAe9B74HvwfAB8EHwgfDB8QHxQfGB8cHyAfJB8oHywfMB80HzgfPB9AH0QfSB9MH1AfVB9YH1wfYB9kH2gfbB9wH3QfeB98H4AfhB+IH4wc="},"xaxis":"x","y":{"dtype":"f8","bdata":"...\u002fsxE7sxE5ADeU1lNdQSkAAAAAAAABJQCRJkiRJkkxAJEmSJEmSTEABAAAAAIBLQFVVVVVVVUdAqqqqqqqqUEAAAAAAACBMQAAAAAAAIExAVVVVVVVVR0BVVVVVVVVHQCmvobyG8kxAqqqqqqqqUEApr6G8hvJMQKqqqqqqqlBAqqqqqqqqQEAAAAAAAABJQA3lNZTXUDpAAAAAAAAASUDFTuzETuw6QAAAAAAAQD9AamlpaWlpPUA="},"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eLOWESS trendline\u003c\u002f ...

# %% [markdown]
# ### Problem 3
#
# Choose one of the graphs produced above (should match the lecture notes) and discuss what you see there:
#
# 1. Which issue are you focusing on.
# 2. What do the graph axis represent?
# 3. Say in words how the United States votes have changed over time.
# 4. How do the United States votes compare to the other countries?
# 5. See if you can come up with one or two questions that interest you about the data in the graph.

# %% [markdown]
# ***#1. Focusing on weapons and material over the years
# #2. Axis represents the amount of votes yes, and the years that the votes happened
# #3. The United States votes had plateaued for a while before stedilly trending downward.
# #4. Although another NATO countries, turkey and United Kingdom both are represented, only turkeys votes trend upwards, unlike the United States.
# #5. What are the amounts of nuclear material that all three of these counrties posess?***

# %% [markdown]
# ### Problem 4
#
# Now go back up to where we picked our three focus countries and choose some different ones. Rerun the analysis. If you want you could choose more than three countries.
#
# Discuss the graph for the same issue but with the new countries.

# %% [markdown]
# ***#1. Focusing on Human Rights over the years
# #2. Axis represents the Percent amount of votes yes, and the years that the votes happened
# #3. The votes for France and Nicaragua both trend upwards while the Russia votes are steady down trending.
# #4. The United States has trended a high yes percentage when it comes to Human Rights which is a similar comparison to france but started higher.
# #5. WHich of these countries has the worst record with human rights abuse?***

# %%
def make_plot(countries,issue):
    '''
    A Python function that takes in the list of countries and issues and makes
    a scatter plot of each issue with a trendline for each country.
    '''
    x_data = []
    y_data = []
    c_data = []
    for cntry in countries:
        my_group = c_groups.get_group((cntry,issue))
        for y in my_group['year'].unique():
            x_data.append(y)
            tot_yes = sum(my_group[my_group['year']==y]['vote']=='yes')
            percent_yes = tot_yes/len(my_group[my_group['year']==y])*100
            y_data.append(percent_yes)
            c_data.append(cntry)

    fig = px.scatter(x=x_data, y=y_data,color=c_data,trendline="lowess",labels={"color": "Country"})

    fig.update_layout(
        title={
            'text': issue + '<br>',
            'y':0.9,
            'x':0.5,
            'xanchor': 'center',
            'yanchor': 'top'})
    fig.update_yaxes(title_text="% Yes")
    fig.update_xaxes(title_text="Year")
    fig.show()
    
for iss in issues:
    make_plot(countries,iss)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.0.min.js" integrity="sha256-Ei4740bWZhaUTQuD6q9yQlgVCMPBz6CZWhevDYPv93A=" crossorigin="anonymous"></script>                <div id="8eac224c-f2cf-439e-ae60-4fb87bd584c3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("8eac224c-f2cf-439e-ae60-4fb87bd584c3")) {                    Plotly.newPlot(                        "8eac224c-f2cf-439e-ae60-4fb87bd584c3",                        [{"hovertemplate":"Country=Nicaragua\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Nicaragua","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Nicaragua","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"mgecB50HngegB6EHogejB6QHpwepB6oHrQeuB68HsQeyB7MHtAe1B7YHtwe4B7kHuge7B7wHvQe+B78HwAfBB8IHwwfEB8UHxgfHB8gHyQfKB8sHzAfNB84HzwfQB9EH0gfTB9QH1gfVB9cH2AfZB9oH2wfcB90H3gffB+AH4QfiB+MH"},"xaxis":"x","y":{"dtype":"f8","bdata":"\..."},"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eLOWESS trendline\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry=Nicaragua\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Nicaragua","marker":{"color":"#636efa","symbol":"circle"},"mode":"lines","name":"Nicaragua","showlegend":false,"x":{"dtype":"i2","bdata":"mgecB50HngegB6EHogejB6QHpwepB6oHrQeuB68HsQeyB7MHtAe1B7YHtwe4B7kHuge7B7wHvQe+B78HwAfBB8IHwwfEB8UHxgfHB8gHyQfKB8sHzAfNB84HzwfQB9EH0gfTB9QH1QfWB9cH2AfZB9oH2wfcB90H3gffB+AH4QfiB+MH"},"xaxis":"x","y":{"dtype":"f8","bdata":"gOLvj0ouN0ALke+Evv85QFE5fyK6bDtAmRiD6X7cPEBhaHsb\u002fcM\u002fQCl0pEWXnUBAl71xASlaQUDTrpzekxdCQM9hzIm\u002f1UJAwPFFl8gTRUASnoH36ZNGQKIioaDBU0dAQhymrqeOSUDkgYX83ElKQGMtNYqOAktAJKQde5psTEC0GM2xXyNNQL01pw3Y5E1A\u002fLIGqRfUTkCNacgO\u002fMpPQCiCgi46ZFBAEusWlavkUEBNagOgoWZRQPALzgIt5lFAivEEyexfUkDFxa+L\u002fNJSQOoIJ53zPlNAWevMAcajU0CDYNoMWBVUQAcngACYblRAFPUXePrAVEANOsRl5gxVQAJ700SXc1VAy5fFX5m0VUBfx+uAiO1VQCZyc11qHVZANh6ocQxoVkDCeK9kFHxWQEQEHE6og1ZAP8\u002fKak6BVkC+xl80wndWQGRQxVmIaVZACX+iRwRYVkCxbofEx0NWQO3cxFqKLVZABRTBTKMWVkCoeeX4Yf5VQARwYx6y5FVAI9hjJ+\u002fJVUDvHV5dfK5VQF5vDmGeklVAlKK3koh2VUA4OM\u002fLZVpVQFMNj35aPlVATP4dg4UiVUDWMQiU\u002fQZVQL4xQurQ61RAy\u002fsArwbRVEDPzAKGn7ZUQP6o96manFRAA3EPb\u002fOCVECxi90FoGlUQDY6KkSVUFRAEuWrcsk3VEDJRlCLNB9UQKJnfQfOBlRA"},"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=
UkA2bfNlNs9SQBone4KNElNA9fkKgV1UU0CxTiIzzZRTQP\u002fSmYkP1FNATRcI3TaNVEBgXvN5bcpUQCckp\u002fsSCFVAQzMDLaxGVUDHgET30oZVQMQm8nE6yVVAwRjsj+BXVkAU8fNEXI5WQOxXiloqwFZAiyZ1gSkFV0A53pbDmEFXQEmD3fWKZldATxcXeepoV0D2ihRm4mRXQAvJardYXldArEex+O1XV0DQZtBAr1NXQGBXflcKUldAZwub98RSV0APeGjDgk9XQBLbqT4dVFdA6cb2aZtaV0CBn2MVwWJXQAbpFNY8bFdACWOIlsZ2V0D\u002fjNb1IIJXQPrJr1F0iFdA\u002fObKr+aWV0DrxdEfmaZXQEyAXPEft1dA7b7FuQnIV0DvTmzpxdhXQAXPbAHo6FdA\u002ffP4rNDzV0D28fM\u002fjf1XQNMKbsQzB1hAQ79hXQ4RWED6NZeNFxtYQBwEhr02JVhA6qUeOlQvWEDDf5fHYTlYQJQXZoRSQ1hAEW0KVBlNWEA1jPUaqlZYQKPl1\u002ff7X1hAUnqMRQZpWEBvWdtJwXFYQJQE7isqelhArQyiIj6CWECaWLcQ+YlYQOiYm3VXkVhAiPQLRF2YWECs2TXtE59YQA=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Russia\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Russia","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Russia","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"nAedB6UHpgenB6gHqQeqB6sHrQeuB68HsAexB7IHswe0B7UHtge3B7gHuQe7B7oHvAe9B74HvwfAB8EHwgfDB8QHxQfGB8cHyAfJB8oHywfMB80HzgfPB9AH0QfSB9MH1AfVB9YH1wfYB9kH2gfbB9wH3QfeB98H4AfhB+IH4wc="},"xaxis":"x","y":{"dtype":"f8","bdata":"\u002fM8z1dAAAAAAADAV0CHh4eHh4dXQEUXXXTRRUtAAAAAAAAATkAAAAAAAABEQAAAAAAAAERAL7rooosuQkAAAAAAAABJQMVO7MRO7EpAHcdxHMdxQ0BP7MRO7MQ+QLdt27Zt20FAt23btm3bQUAAAAAAAAA+QKqqqqqqqkBAAAAAAADgRUCrqqqqqqo6QAAAAAAA4EVAt23btm3bQUAAAAAAAMBCQCmvobyG8kxAPc\u002fzPM\u002fzTkBDeQ3lNZRPQMMwDMMwDENAqqqqqqqqMEDbtm3btm01QNdQXkN5DTVAAAAAAAAAOUCyEzuxEzszQAAAAAAAwDJApqWlpaWlMUA="},"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eLOWESS trendline\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry=Russia\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Russia","marker":{"color":"#E ...

# %% [markdown]
# --------------------------------
# ### You are done with the homework... now what?
# --------------------------------
#
# 1. Save your changes.
# 2. In the Git tab, **Stage** your changed files - use the (+) button next to the file.
# 3. **Commit** your changes by entering a summary and pushing commit.
# 4. **Push** your changes using the cloud button.
# 5. Check that your changes are on your GitHub repo (online)
# 6. **TAKE THE DAILY QUIZ ON CANVAS** the quiz will ask you to copy and past the HTTPS link to your repo for the day.
# 7. Come to class and get your questions answered.
#
# At the end of the week  you will submit your final versions of the homework on Canvas for grading. For this you can just drag and drop the HW.ipynb files into canvas.
#
# **IMPORTANT** If this is confusing this first week, don't worry, I can help you and I will be really flexible about these first few deadlines.
